# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.arange(0,10)

# %%
y=2*x

# %%
plt.plot(x,y)
plt.title('String Title')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xlim(0,9)
plt.ylim(0,18)
plt.savefig('C:\\Users\\BRAVO15\\Desktop\\python\\figure1.jpeg')
plt.show()
plt.savefig('C:\\Users\\BRAVO15\\Desktop\\python\\figure2.jpeg')

# %%
#help(plt.savefig)

# %%
plt.savefig
